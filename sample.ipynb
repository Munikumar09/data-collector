# %%
import json
from app.trascription_utils import common_ss,calculate_similarity
from pathlib import Path
from IPython.display import Audio

# %%
transcript_file=Path("/home/munikumar-17774/Desktop/data/collect_data/percent_match.json")
audio_dir=Path("/home/munikumar-17774/Desktop/data/collect_data/audio/jYkQvseKzeg")

# %%
# Out:
# PosixPath('/home/munikumar-17774/Desktop/data/collect_data/audio/jYkQvseKzeg.mp3')

# %%
with open(transcript_file, 'r') as f:
    transcript = json.load(f)

# %%
len(transcript)
# Out:
# 174

# %%
sixty_percent_match={}

# %%
c=0
for key,value in transcript.items():
    if value["percent_match"]> 60:
        sixty_percent_match[key]=value

# %%
six_ls=list(sixty_percent_match.items())

# %%
i=2

# %%
print(f"audio_name {six_ls[i][0]}")
print(f"original text {six_ls[i][1]['normal']}")
print(f"nemo txt : {six_ls[i][1]['nemo']}")
print(f"percent_match : {six_ls[i][1]['percent_match']}")
Audio(audio_dir.joinpath(six_ls[i][0]),)
# Out:
# audio_name 77.359_81.54899999999999.mp3
# original text क्या? कि यहां पे 90% वाले ना मोबाइल के साथ रहेंगे।
# nemo txt : ा कि यहां पर नाइनटी परसेंट वाले तो मोबाइल के साथ रहे हा
# percent_match : 60.952380952380956
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
